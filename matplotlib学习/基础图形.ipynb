# %% [markdown]
# ## 2.1bar()📊柱状图

# %%
#_*_coding:uft-8_*
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['axes.unicode_minus']=False

# %%
x = list(range(1,9))
x
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
import numpy as np
y = np.random.randint(1,9,8)

# %%
y
# Out:
# array([5, 7, 3, 2, 1, 1, 8, 6])

# %%
plt.figure(figsize=(14,7))
plt.bar(x,y,align='center',color='c',hatch='/',tick)
plt.xlabel('box number',fontsize=19)
plt.ylabel('box weight(kg)',fontsize=20)
plt.show()

# %% [markdown]
# ## 2.2barh()条形图

# %%
import matplotlib as mpl
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(1,9)
y = np.random.randint(2,9,8)

# %%
x
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
y
# Out:
# array([4, 6, 2, 8, 5, 2, 8, 4])

# %%
plt.figure(figsize=(14,7))
plt.barh(x,y,align='center',color='c',
        tick_label=['q','a','c','e','r','j','b','p'],
        hatch='/')
plt.xlabel('box weight(kg)')
plt.ylabel('box number')
plt.show()

# %% [markdown]
# ## 2.3hist()直方图

# %%
boxWeight = np.random.randint(0,10,100)
boxWeight
# Out:
# array([6, 1, 2, 0, 6, 0, 6, 5, 6, 2, 5, 9, 1, 1, 0, 6, 0, 0, 1, 5, 7, 0,
#        8, 8, 6, 2, 3, 4, 2, 5, 2, 2, 8, 1, 4, 7, 7, 5, 3, 4, 4, 1, 4, 4,
#        6, 5, 9, 8, 2, 6, 9, 6, 2, 2, 1, 9, 3, 4, 0, 4, 4, 5, 6, 2, 5, 7,
#        8, 7, 0, 2, 6, 6, 1, 2, 8, 0, 7, 1, 2, 8, 1, 8, 7, 0, 7, 9, 1, 3,
#        1, 3, 7, 4, 3, 4, 9, 3, 8, 2, 9, 1])

# %%
x = boxWeight

# %%
bins = range(0,11,1)
bins
# Out:
# range(0, 11)

# %%
plt.figure(figsize=(14,7))
plt.hist(x,bins=bins,color='g',histtype='bar',
        rwidth=1,alpha=0.6)
plt.xlabel('box weight(kg)')
plt.ylabel('sold number')
plt.show()

# %% [markdown]
# ## 2.2pie()

# %%
kinds = '1','2','3','4',
colors = ['#e41a1c','#377eb8','#4daf4a','#984ea3']
soldNums = [0.05,0.45,0.15,0.35]

# %%
plt.figure(figsize=(14,7))
plt.pie(soldNums,labels=kinds,
        autopct='%3.1f%%',startangle=60,colors=colors)
plt.show()

# %% [markdown]
# ## 2.5polar()极线图

# %%
barSlices = 12
theta = np.linspace(0.0,2*np.pi,barSlices,endpoint=False)
r = 30*np.random.rand(barSlices)

# %%
barSlices
# Out:
# 12

# %%
theta
# Out:
# array([0.        , 0.52359878, 1.04719755, 1.57079633, 2.0943951 ,
#        2.61799388, 3.14159265, 3.66519143, 4.1887902 , 4.71238898,
#        5.23598776, 5.75958653])

# %%
r
# Out:
# array([25.93334354,  1.92251346, 28.47823377, 14.48725671, 18.18720456,
#        17.14433782,  6.73587344,  1.54413343, 17.27035206, 15.955438  ,
#        24.89048827,  2.99689931])

# %%
plt.figure(figsize=(14,7))
plt.polar(theta,r,color='chartreuse',
          lw=2,marker='*',mfc='b',ms=10)
plt.show()

# %% [markdown]
# ## 2.6scatter()气泡图

# %%
plt.figure(figsize=(14,7))
a = np.random.randn(100)
b = np.random.randn(100)
plt.scatter(a,b,s=np.power(10*a+20*b,2),
           c=np.random.rand(100),cmap=mpl.cm.RdYlBu,
           marker='o')
plt.show()

# %% [markdown]
# ## 2.7stem()棉棒图

# %%
x = np.linspace(0.5,2*np.pi,20)
y = np.random.randn(20)
plt.figure(figsize=(14,7))
plt.stem(x,y,linefmt='-',markerfmt='o',basefmt='-')
plt.show()

# %% [markdown]
# ## 2.8boxplot()箱型图

# %%
x = np.random.randn(1000)
plt.figure(figsize=(14,7))
plt.boxplot(x)
plt.grid(axis="y",ls=':',lw=1,color='gray',alpha=0.4)
plt.show()

# %% [markdown]
# ## 2.9errorbar()误差棒图

# %%
x = np.linspace(0.1,0.6,6)
y = np.exp(x)

# %%
plt.figure(figsize=(14,7))
plt.errorbar(x,y,fmt='bo:',xerr=0.02,yerr=0.2)
plt.show()
